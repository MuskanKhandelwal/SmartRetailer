# %%
import numpy as np
import pandas as pd
import pickle   # for saving/loading models
from sklearn.preprocessing import StandardScaler
import joblib

# %%
import joblib
features_df = pd.read_parquet("panel_augmented2.parquet")
model_filepath = "market_simulator_model2.joblib"
demand_model = joblib.load(model_filepath)

# %%
model_features = [
    "lag_units_1w",
    "lag_units_2w",
    "lag_units_3w",
    "lag_units_4w",
    "rolling_mean_4w",
    "rolling_std_4w",
    "rolling_mean_8w",
    "rolling_std_8w",
    "rolling_mean_12w",
    "rolling_std_12w",
    "unit_price",
    "discount_depth",
    "price_change",
    "price_vs_ref_ratio",
    "ref_price",
    "promo_flag",
    "promo_code_encoded",
    "month",
    "quarter",
    "weekofyr",
    "is_month_start",
    "is_month_end",
    "has_special_event",
    "temp_mean",
    "temp_max",
    "precip_sum",
    "weather_missing_flag",
    "cpi_bev",
    "brand_encoded",
    "margin_pct",
    "store"
]

# %%
upc_list = [7800000075,7336070997,1690000302,4900000981,7241009310,5490000029,4100010728,1200000085,1200000013,1660000064,4900000551]

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np

class MultiUPCEnv(gym.Env):
    def __init__(
        self,
        demand_model,
        features_df,
        upc_list,
        price_change_bounds=(-0.30, 0.30),
        noise_std=0.02
    ):
        super(MultiUPCEnv, self).__init__()

        self.demand_model = demand_model
        self.features_df = features_df
        self.upc_list = upc_list
        self.price_change_bounds = price_change_bounds
        self.noise_std = noise_std

        self.current_upc = None
        self.week_idx_ptr = None
        self.weeks = None
        self.current_price = None

        # --------------------------
        # OBSERVATION SPACE (continuous)
        # --------------------------
        self.state_features = [
            f for f in model_features if f not in ["unit_price", "price_change"]
        ]

        self.obs_dim = len(self.state_features) + 3   # price, prev_units, prev_price_change
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.obs_dim,), dtype=np.float32
        )

        # --------------------------
        # ACTION SPACE (continuous)
        # PPO outputs value in [-1, 1]; we scale it to price_change_bounds
        # --------------------------
        self.action_space = spaces.Box(
            low=np.array([-1.0]), high=np.array([1.0]), dtype=np.float32
        )

    def _scale_action(self, a):
        """convert [-1,1] → [min_change,max_change]"""
        low, high = self.price_change_bounds
        return low + (a + 1) * (high - low) / 2

    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
    
        self.current_upc = np.random.choice(self.upc_list)
        df_u = self.features_df[self.features_df["upc"] == self.current_upc]
    
        self.weeks = sorted(df_u["week_x"].unique())
        self.week_idx_ptr = 0
    
        row = df_u[df_u["week_x"] == self.weeks[0]].iloc[0]
        self.current_price = float(row["unit_price"])
    
        self.prev_units = 0.0
        self.prev_price_change = 0.0
    
        obs = self._get_state(row)
        return obs, {}


    def _get_state(self, row):
        base_state = np.array(
            [row[feat] for feat in self.state_features], dtype=np.float32
        )
        extended = np.array(
            [self.current_price, self.prev_units, self.prev_price_change],
            dtype=np.float32
        )
        return np.nan_to_num(np.concatenate([base_state, extended]))

    def step(self, action):

        df_u = self.features_df[self.features_df["upc"] == self.current_upc]
    
        # scale action from [-1, 1] to price_change_bounds
        price_change = float(self._scale_action(float(action[0])))
    
        new_price = float(
            np.clip(self.current_price * (1.0 + price_change), 0.5, 10.0)
        )
    
        row = df_u[df_u["week_x"] == self.weeks[self.week_idx_ptr]].iloc[0]
    
        # prepare input for demand model
        model_input = row.copy()
        model_input["unit_price"] = new_price
        model_input["price_change"] = price_change
    
        X = model_input[model_features].values.reshape(1, -1)
        base_units = self.demand_model.predict(X)[0]
        units = max(base_units * (1 + np.random.normal(0, self.noise_std)), 0)
    
        cost = row.get("cost_real", row.get("unit_cost", 0))
        profit = (new_price - cost) * units
    
        reward = profit / 100.0
    
        # update stored vars
        self.prev_units = units
        self.prev_price_change = price_change
        self.current_price = new_price
    
        # move to next week
        self.week_idx_ptr += 1
    
        terminated = self.week_idx_ptr >= len(self.weeks)
        truncated = False  # PPO never truncates episodes
    
        info = {"profit": profit, "price": new_price, "units": units}
    
        if terminated:
            # return dummy obs required by SB3
            obs = np.zeros(self.obs_dim, dtype=np.float32)
            return obs, reward, terminated, truncated, info
    
        next_row = df_u[df_u["week_x"] == self.weeks[self.week_idx_ptr]].iloc[0]
        next_state = self._get_state(next_row)
    
        return next_state, reward, terminated, truncated, info

# %%
# !pip install --user stable-baselines3
# Out:
# Collecting stable-baselines3
#   Using cached stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from stable-baselines3) (1.2.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from stable-baselines3) (2.0.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from stable-baselines3) (2.5.1)
# Requirement already satisfied: cloudpickle in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from stable-baselines3) (2.3.2)
# Requirement already satisfied: matplotlib in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: networkx in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/miniconda/envs/eai/lib/python3.10/site-packages (from pandas->stable-baselines3) (2025.2)
# Using cached stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.7.0

# %%
import site
import sys
sys.path.append(site.USER_SITE)

# %%
import sys
sys.path.append("./local_lib")

try:
    from stable_baselines3 import PPO
    print("✅ Stable-Baselines3 is ready!")
except Exception as e:
    print("❌ Import error:", e)
# Out:
# ✅ Stable-Baselines3 is ready!

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor

def make_env():
    return Monitor(MultiUPCEnv(
        demand_model=demand_model,
        features_df=features_df,
        upc_list=upc_list,
        noise_std=0.02
    ))

# Vectorized env (helps with PPO stability)
env = DummyVecEnv([make_env])

# PPO model
model = PPO(
    policy="MlpPolicy",
    env=env,
    learning_rate=3e-4,
    n_steps=2048,
    batch_size=256,
    n_epochs=10,
    gamma=0.99,
    gae_lambda=0.95,
    clip_range=0.2,
    verbose=1,
    tensorboard_log="./ppo_logs/"
)

# Train
model.learn(total_timesteps=500_000)
model.save("ppo_pricing_model")
# Out:
# Using cuda device
# Logging to ./ppo_logs/PPO_2
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# /home/khandelwal.mu/.local/lib/python3.10/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 389      |
# |    ep_rew_mean     | -18.4    |
# | time/              |          |
# |    fps             | 51       |
# |    iterations      | 1        |
# |    time_elapsed    | 39       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 388          |
# |    ep_rew_mean          | 112          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 2            |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0096813785 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -0.0541      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.25         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0136      |
# |    std                  | 0.988        |
# |    value_loss           | 9.48         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 382          |
# |    ep_rew_mean          | 143          |
# | time/                   |              |
# |    fps                  | 50           |
# |    iterations           | 3            |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0015511677 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -0.0157      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 175          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0038      |
# |    std                  | 0.985        |
# |    value_loss           | 394          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 384         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 4           |
# |    time_elapsed         | 164         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.005523488 |
# |    clip_fraction        | 0.0119      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.00796     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00545    |
# |    std                  | 0.985       |
# |    value_loss           | 221         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 385           |
# |    ep_rew_mean          | 321           |
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 5             |
# |    time_elapsed         | 208           |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00046196897 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.0366       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 691           |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00172      |
# |    std                  | 0.984         |
# |    value_loss           | 1.45e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 385           |
# |    ep_rew_mean          | 338           |
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 6             |
# |    time_elapsed         | 250           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00043924127 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.000594      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 360           |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00139      |
# |    std                  | 0.984         |
# |    value_loss           | 708           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 374         |
# |    ep_rew_mean          | 371         |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 7           |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.001130864 |
# |    clip_fraction        | 0.000195    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -0.00844    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 335         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00216    |
# |    std                  | 0.983       |
# |    value_loss           | 572         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 376           |
# |    ep_rew_mean          | 404           |
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 8             |
# |    time_elapsed         | 335           |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 0.00081560144 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.00243      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 408           |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.00166      |
# |    std                  | 0.982         |
# |    value_loss           | 946           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 375          |
# |    ep_rew_mean          | 455          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 9            |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0009864515 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00105      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 392          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00172     |
# |    std                  | 0.982        |
# |    value_loss           | 883          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 375           |
# |    ep_rew_mean          | 447           |
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 10            |
# |    time_elapsed         | 423           |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 4.7935726e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | -0.00196      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.09e+03      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000763     |
# |    std                  | 0.983         |
# |    value_loss           | 2.04e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | 442          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 11           |
# |    time_elapsed         | 464          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0009658603 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00168      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 393          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00182     |
# |    std                  | 0.983        |
# |    value_loss           | 646          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 374           |
# |    ep_rew_mean          | 453           |
# | time/                   |               |
# |    fps                  | 48            |
# |    iterations           | 12            |
# |    time_elapsed         | 505           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00052426936 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.4          |
# |    explained_variance   | 0.00275       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 100           |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.00176      |
# |    std                  | 0.979         |
# |    value_loss           | 196           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | 456         |
# | time/                   |             |
# |    fps                  | 48          |
# |    iterations           | 13          |
# |    time_elapsed         | 548         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.000270149 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.00193     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 270         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00108    |
# |    std                  | 0.978       |
# |    value_loss           | 564         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | 431          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 14           |
# |    time_elapsed         | 586          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0010457016 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.000942     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 487          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00191     |
# |    std                  | 0.978        |
# |    value_loss           | 857          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 349          |
# |    ep_rew_mean          | 421          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 15           |
# |    time_elapsed         | 627          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0005757083 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.00265      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 87           |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00201     |
# |    std                  | 0.977        |
# |    value_loss           | 203          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 345          |
# |    ep_rew_mean          | 432          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 16           |
# |    time_elapsed         | 668          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0050446116 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00242      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 122          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00574     |
# |    std                  | 0.974        |
# |    value_loss           | 227          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 340          |
# |    ep_rew_mean          | 429          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 17           |
# |    time_elapsed         | 707          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0010206263 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00108      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 523          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00284     |
# |    std                  | 0.974        |
# |    value_loss           | 1.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 430          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 18           |
# |    time_elapsed         | 745          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0026341775 |
# |    clip_fraction        | 0.00586      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00417      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00328     |
# |    std                  | 0.975        |
# |    value_loss           | 247          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 433          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 19           |
# |    time_elapsed         | 787          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0021954377 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0118       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.4         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00527     |
# |    std                  | 0.972        |
# |    value_loss           | 119          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | 421          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 20           |
# |    time_elapsed         | 825          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0005664913 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.164        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47           |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00276     |
# |    std                  | 0.974        |
# |    value_loss           | 107          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 329         |
# |    ep_rew_mean          | 404         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 21          |
# |    time_elapsed         | 867         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003386395 |
# |    clip_fraction        | 0.0107      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.152       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00297    |
# |    std                  | 0.974       |
# |    value_loss           | 181         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 402         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 22          |
# |    time_elapsed         | 912         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.002113782 |
# |    clip_fraction        | 0.00278     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69.2        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00268    |
# |    std                  | 0.974       |
# |    value_loss           | 196         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | 415         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 23          |
# |    time_elapsed         | 955         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.003948395 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 70          |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00549    |
# |    std                  | 0.974       |
# |    value_loss           | 158         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 412          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 24           |
# |    time_elapsed         | 997          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0003327437 |
# |    clip_fraction        | 0.000146     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0653       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 960          |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00155     |
# |    std                  | 0.975        |
# |    value_loss           | 1.98e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 393          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 25           |
# |    time_elapsed         | 1037         |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0016695411 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0467       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00414     |
# |    std                  | 0.972        |
# |    value_loss           | 245          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 326          |
# |    ep_rew_mean          | 398          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 26           |
# |    time_elapsed         | 1080         |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0017801058 |
# |    clip_fraction        | 0.00303      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0939       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 274          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00314     |
# |    std                  | 0.972        |
# |    value_loss           | 560          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 326           |
# |    ep_rew_mean          | 424           |
# | time/                   |               |
# |    fps                  | 49            |
# |    iterations           | 27            |
# |    time_elapsed         | 1122          |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00013750236 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.39         |
# |    explained_variance   | 0.0925        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 756           |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.00165      |
# |    std                  | 0.973         |
# |    value_loss           | 1.79e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 322          |
# |    ep_rew_mean          | 404          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 28           |
# |    time_elapsed         | 1161         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0001492454 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.07         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 767          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00205     |
# |    std                  | 0.972        |
# |    value_loss           | 1.23e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 412          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 29           |
# |    time_elapsed         | 1202         |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0017363816 |
# |    clip_fraction        | 0.00137      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.422        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 130          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00308     |
# |    std                  | 0.973        |
# |    value_loss           | 214          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 427          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 30           |
# |    time_elapsed         | 1246         |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0007687585 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.199        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 580          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00213     |
# |    std                  | 0.972        |
# |    value_loss           | 1.21e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 342          |
# |    ep_rew_mean          | 456          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 31           |
# |    time_elapsed         | 1288         |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0010343709 |
# |    clip_fraction        | 0.00298      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.232        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 230          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00412     |
# |    std                  | 0.97         |
# |    value_loss           | 489          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 338          |
# |    ep_rew_mean          | 439          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 32           |
# |    time_elapsed         | 1326         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0005062778 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.0773       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 644          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00223     |
# |    std                  | 0.97         |
# |    value_loss           | 1.43e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 338          |
# |    ep_rew_mean          | 436          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 33           |
# |    time_elapsed         | 1369         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0025000006 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.446        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 143          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00406     |
# |    std                  | 0.97         |
# |    value_loss           | 276          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | 452         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 34          |
# |    time_elapsed         | 1410        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.003838236 |
# |    clip_fraction        | 0.0179      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 87.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00412    |
# |    std                  | 0.97        |
# |    value_loss           | 171         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 483          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 35           |
# |    time_elapsed         | 1452         |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0009175639 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 322          |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0029      |
# |    std                  | 0.97         |
# |    value_loss           | 649          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 492          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 36           |
# |    time_elapsed         | 1494         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0011153867 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.173        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 612          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00274     |
# |    std                  | 0.972        |
# |    value_loss           | 1.26e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 520          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 37           |
# |    time_elapsed         | 1538         |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0011941574 |
# |    clip_fraction        | 0.00332      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0047      |
# |    std                  | 0.969        |
# |    value_loss           | 480          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 349          |
# |    ep_rew_mean          | 532          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 38           |
# |    time_elapsed         | 1580         |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0038358984 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 765          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00466     |
# |    std                  | 0.968        |
# |    value_loss           | 1.62e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 538          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 39           |
# |    time_elapsed         | 1621         |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0014374861 |
# |    clip_fraction        | 0.00229      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.275        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 490          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00449     |
# |    std                  | 0.974        |
# |    value_loss           | 871          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 518          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 40           |
# |    time_elapsed         | 1665         |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0020291903 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.555        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 161          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00544     |
# |    std                  | 0.976        |
# |    value_loss           | 330          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 528          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 41           |
# |    time_elapsed         | 1710         |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0034705433 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.619        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 109          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00452     |
# |    std                  | 0.974        |
# |    value_loss           | 225          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 527          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 42           |
# |    time_elapsed         | 1754         |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0005751685 |
# |    clip_fraction        | 0.000635     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 383          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00281     |
# |    std                  | 0.971        |
# |    value_loss           | 726          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 346          |
# |    ep_rew_mean          | 499          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 43           |
# |    time_elapsed         | 1795         |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0016706618 |
# |    clip_fraction        | 0.00313      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 113          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00361     |
# |    std                  | 0.972        |
# |    value_loss           | 251          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 44          |
# |    time_elapsed         | 1834        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.002558959 |
# |    clip_fraction        | 0.00591     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.9        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00258    |
# |    std                  | 0.972       |
# |    value_loss           | 185         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 353          |
# |    ep_rew_mean          | 509          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 45           |
# |    time_elapsed         | 1876         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0033265236 |
# |    clip_fraction        | 0.00688      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 355          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00428     |
# |    std                  | 0.97         |
# |    value_loss           | 623          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 530          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 46           |
# |    time_elapsed         | 1920         |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0039186073 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.356        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 598          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00445     |
# |    std                  | 0.971        |
# |    value_loss           | 1.35e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 354         |
# |    ep_rew_mean          | 523         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 47          |
# |    time_elapsed         | 1961        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.001456086 |
# |    clip_fraction        | 0.00303     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 386         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.004      |
# |    std                  | 0.973       |
# |    value_loss           | 883         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 354          |
# |    ep_rew_mean          | 518          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 48           |
# |    time_elapsed         | 2005         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0024271165 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.526        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 120          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00508     |
# |    std                  | 0.969        |
# |    value_loss           | 254          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 357         |
# |    ep_rew_mean          | 513         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 49          |
# |    time_elapsed         | 2046        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.001898964 |
# |    clip_fraction        | 0.00342     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 216         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00418    |
# |    std                  | 0.965       |
# |    value_loss           | 459         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 363          |
# |    ep_rew_mean          | 539          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 50           |
# |    time_elapsed         | 2099         |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0008093325 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.621        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 153          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00346     |
# |    std                  | 0.963        |
# |    value_loss           | 265          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 366          |
# |    ep_rew_mean          | 551          |
# | time/                   |              |
# |    fps                  | 48           |
# |    iterations           | 51           |
# |    time_elapsed         | 2140         |
# ...
# |    loss                 | 18.6        |
# |    n_updates            | 2270        |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.562       |
# |    value_loss           | 38.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | 481         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 229         |
# |    time_elapsed         | 9495        |
# |    total_timesteps      | 468992      |
# | train/                  |             |
# |    approx_kl            | 0.006622496 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 225         |
# |    n_updates            | 2280        |
# |    policy_gradient_loss | -0.00705    |
# |    std                  | 0.559       |
# |    value_loss           | 399         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | 500         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 230         |
# |    time_elapsed         | 9534        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.010554593 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.559       |
# |    value_loss           | 233         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 331         |
# |    ep_rew_mean          | 486         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 231         |
# |    time_elapsed         | 9575        |
# |    total_timesteps      | 473088      |
# | train/                  |             |
# |    approx_kl            | 0.008377107 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 488         |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00971    |
# |    std                  | 0.557       |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 476          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 232          |
# |    time_elapsed         | 9616         |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0079323165 |
# |    clip_fraction        | 0.0404       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.835       |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 124          |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 0.558        |
# |    value_loss           | 192          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | 476         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 233         |
# |    time_elapsed         | 9660        |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.013114134 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 267         |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.555       |
# |    value_loss           | 533         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 337         |
# |    ep_rew_mean          | 480         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 234         |
# |    time_elapsed         | 9702        |
# |    total_timesteps      | 479232      |
# | train/                  |             |
# |    approx_kl            | 0.009730183 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 311         |
# |    n_updates            | 2330        |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.551       |
# |    value_loss           | 618         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 346         |
# |    ep_rew_mean          | 478         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 235         |
# |    time_elapsed         | 9743        |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 0.013206003 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.2        |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.55        |
# |    value_loss           | 258         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 343         |
# |    ep_rew_mean          | 498         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 236         |
# |    time_elapsed         | 9784        |
# |    total_timesteps      | 483328      |
# | train/                  |             |
# |    approx_kl            | 0.012063744 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.823      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.3        |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.553       |
# |    value_loss           | 129         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 341         |
# |    ep_rew_mean          | 489         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 237         |
# |    time_elapsed         | 9824        |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.009094678 |
# |    clip_fraction        | 0.0519      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 484         |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00843    |
# |    std                  | 0.554       |
# |    value_loss           | 1.19e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 478          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 238          |
# |    time_elapsed         | 9866         |
# |    total_timesteps      | 487424       |
# | train/                  |              |
# |    approx_kl            | 0.0062725684 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.9          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 178          |
# |    n_updates            | 2370         |
# |    policy_gradient_loss | -0.0143      |
# |    std                  | 0.554        |
# |    value_loss           | 525          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 474          |
# | time/                   |              |
# |    fps                  | 49           |
# |    iterations           | 239          |
# |    time_elapsed         | 9910         |
# |    total_timesteps      | 489472       |
# | train/                  |              |
# |    approx_kl            | 0.0084627615 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.91         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 291          |
# |    n_updates            | 2380         |
# |    policy_gradient_loss | -0.0122      |
# |    std                  | 0.553        |
# |    value_loss           | 595          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 337         |
# |    ep_rew_mean          | 504         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 240         |
# |    time_elapsed         | 9952        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.009756556 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 265         |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.551       |
# |    value_loss           | 561         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 337         |
# |    ep_rew_mean          | 486         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 241         |
# |    time_elapsed         | 9990        |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.006222221 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 312         |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.547       |
# |    value_loss           | 858         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 340         |
# |    ep_rew_mean          | 480         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 242         |
# |    time_elapsed         | 10031       |
# |    total_timesteps      | 495616      |
# | train/                  |             |
# |    approx_kl            | 0.011331805 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.815      |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.7        |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.546       |
# |    value_loss           | 172         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 343         |
# |    ep_rew_mean          | 479         |
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 243         |
# |    time_elapsed         | 10075       |
# |    total_timesteps      | 497664      |
# | train/                  |             |
# |    approx_kl            | 0.015426087 |
# |    clip_fraction        | 0.0796      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.814      |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 61          |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.545       |
# |    value_loss           | 282         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 346        |
# |    ep_rew_mean          | 510        |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 244        |
# |    time_elapsed         | 10116      |
# |    total_timesteps      | 499712     |
# | train/                  |            |
# |    approx_kl            | 0.01405401 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.811     |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.4       |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | -0.0105    |
# |    std                  | 0.543      |
# |    value_loss           | 93.3       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 350        |
# |    ep_rew_mean          | 528        |
# | time/                   |            |
# |    fps                  | 49         |
# |    iterations           | 245        |
# |    time_elapsed         | 10159      |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.00818074 |
# |    clip_fraction        | 0.0605     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.808     |
# |    explained_variance   | 0.747      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 424        |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 0.542      |
# |    value_loss           | 989        |
# ----------------------------------------

# %%
from stable_baselines3 import PPO
model = PPO.load("ppo_pricing_model")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
def simulate_upc(upc):
    env = MultiUPCEnv(
        demand_model=demand_model,
        features_df=features_df,
        upc_list=upc_list,       # force env to use only this UPC
        noise_std=0.0
    )
    
    obs, _ = env.reset()
    total_profit = 0
    done = False
    truncated = False

    while not done and not truncated:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(action)
        total_profit += info["profit"]

    return total_profit

# %%
profits = {}
for upc in upc_list:
    p = simulate_upc(upc)
    profits[upc] = p
    print(f"UPC {upc}: Profit = ${p:,.2f}")
# Out:
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 7800000075: Profit = $39,089.13
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 7336070997: Profit = $19,536.66
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1690000302: Profit = $1,353.05
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 4900000981: Profit = $82,915.74
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 7241009310: Profit = $1,353.05
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 5490000029: Profit = $20,363.10
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 4100010728: Profit = $20,363.10
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1200000085: Profit = $23,400.31
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1200000013: Profit = $39,089.13
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1660000064: Profit = $19,738.04
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 4900000551: Profit = $19,536.66

# %%
upc_list = [418,419,422,425,427,430]

# %%
profits = {}
for upc in upc_list:
    p = simulate_upc(upc)
    profits[upc] = p
    print(f"UPC {upc}: Profit = ${p:,.2f}")
# Out:
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 418: Profit = $1,832.19
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 419: Profit = $1,869.04
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 422: Profit = $1,832.19
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 425: Profit = $1,832.19
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 427: Profit = $2,777.75
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 430: Profit = $1,869.04

# %%
upc_list = [1200000230, 4900000639, 420, 4900000663, 1200000231, 1200000013, 450, 4900001884, 4900000634, 1200000844]

# %%
profits = {}
for upc in upc_list:
    p = simulate_upc(upc)
    profits[upc] = p
    print(f"UPC {upc}: Profit = ${p:,.2f}")
# Out:
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1200000230: Profit = $409,403.53
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 4900000639: Profit = $409,403.53
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 420: Profit = $163,094.96
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 4900000663: Profit = $372,639.13
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1200000231: Profit = $31,242.37
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1200000013: Profit = $329,353.69
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 450: Profit = $31,242.37
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 4900001884: Profit = $143,256.08
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 4900000634: Profit = $329,353.69
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /opt/miniconda/envs/eai/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# UPC 1200000844: Profit = $296,294.72
